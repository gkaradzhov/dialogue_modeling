# %%
# %cd /Users/georgi/dev/dialogue_modeling
# Out:
# /Users/georgi/dev/dialogue_modeling

# %%
from collections import defaultdict

# %%
from supporting_classifiers.agreement_classifier import *
from solution_tracker.simple_sol import solution_tracker, process_raw_to_solution_tracker
import spacy
import string
from read_data import read_solution_annotaions, read_wason_dump, read_3_lvl_annotation_file
import pandas as pd
from featurisers.raw_wason_featuriser import get_y

# %%
raw_data = read_wason_dump('data/all/')

# %%
conv = raw_data[3].raw_db_conversation

# %%
conv
# Out:
# [{'message_id': '48e5ef64-7e50-4f92-a19e-200b19539ca1',
#   'user_name': 'SYSTEM',
#   'user_id': '-1',
#   'message_type': 'WASON_INITIAL',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': False},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'UKN',
#   'timestamp': '2020-08-19 18:22:18.553825+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'f993decc-a252-448c-8e6a-ce23da89d84f',
#   'user_name': 'Bat',
#   'user_id': 'f72989875dbe4a63a214055059ca0fc4',
#   'message_type': 'JOIN_ROOM',
#   'content': '',
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:22:18.971115+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'acbee860-1734-448d-8ba7-9dcc786fa9a0',
#   'user_name': 'Hedgehog',
#   'user_id': '3846adbce13f46f987bf284ce3dad593',
#   'message_type': 'JOIN_ROOM',
#   'content': '',
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:22:36.466840+00:00',
#   'user_type': 'participant'},
#  {'message_id': '2795ad67-f823-4336-ae29-ace7ce1cb5e1',
#   'user_name': 'Kiwi',
#   'user_id': '72e69531e95b4ec2bd33724873efc884',
#   'message_type': 'JOIN_ROOM',
#   'content': '',
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:22:41.370706+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'a96119a2-d85b-466b-9518-ecb87b9861f0',
#   'user_name': 'SYSTEM',
#   'user_id': '-1',
#   'message_type': 'ROUTING_TIMER_STARTED',
#   'content': '1',
#   'user_status': 'UKN',
#   'timestamp': '2020-08-19 18:22:41.587494+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'd407658f-928c-42c4-b546-c813f7cbfec3',
#   'user_name': 'Hedgehog',
#   'user_id': '3846adbce13f46f987bf284ce3dad593',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:23:16.863853+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'e1217773-70be-4cbf-b1c5-493f144b513e',
#   'user_name': 'Hedgehog',
#   'user_id': '3846adbce13f46f987bf284ce3dad593',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:23:18.237418+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'daa1f58c-8623-4b52-b260-89361112fe0e',
#   'user_name': 'Hedgehog',
#   'user_id': '3846adbce13f46f987bf284ce3dad593',
#   'message_type': 'WASON_SUBMIT',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:23:20.439087+00:00',
#   'user_type': 'participant'},
#  {'message_id': '9af586f2-b4a7-4f7d-8cf9-618d71605470',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'JOIN_ROOM',
#   'content': '',
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:23:22.789478+00:00',
#   'user_type': 'participant'},
#  {'message_id': '3a9a2573-3f6a-4e03-a0ee-337ede33245c',
#   'user_name': 'Bat',
#   'user_id': 'f72989875dbe4a63a214055059ca0fc4',
#   'message_type': 'ROUTING_TIMER_ELAPSED',
#   'content': "[{'value': 'G', 'checked': False}, {'value': '2', 'checked': False}, {'value': '7', 'checked': False}, {'value': 'A', 'checked': False}]",
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:23:42.711610+00:00',
#   'user_type': 'participant'},
#  {'message_id': '7aa86ff9-973f-479b-b28e-a998478c79dc',
#   'user_name': 'Hedgehog',
#   'user_id': '3846adbce13f46f987bf284ce3dad593',
#   'message_type': 'ROUTING_TIMER_ELAPSED',
#   'content': "[{'value': 'G', 'checked': False}, {'value': '2', 'checked': False}, {'value': '7', 'checked': False}, {'value': 'A', 'checked': False}]",
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:23:42.814881+00:00',
#   'user_type': 'participant'},
#  {'message_id': '98038aed-3ed5-4aeb-b7f8-a4bb2a007350',
#   'user_name': 'Kiwi',
#   'user_id': '72e69531e95b4ec2bd33724873efc884',
#   'message_type': 'ROUTING_TIMER_ELAPSED',
#   'content': '',
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:23:43.100825+00:00',
#   'user_type': 'participant'},
#  {'message_id': '8d43dc55-5c2a-430c-aa9a-6c2dc33eee3e',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:23:58.792259+00:00',
#   'user_type': 'participant'},
#  {'message_id': '773e39ac-8f97-4535-a0a0-64833c48f1ff',
#   'user_name': 'Kiwi',
#   'user_id': '72e69531e95b4ec2bd33724873efc884',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:24:08.550337+00:00',
#   'user_type': 'participant'},
#  {'message_id': '65621f86-f627-4c40-a92d-c7570e7b5ba3',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_SUBMIT',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:24:09.402514+00:00',
#   'user_type': 'participant'},
#  {'message_id': '68a90278-c7ad-4acf-9804-e2ff19b9f4e4',
#   'user_name': 'Kiwi',
#   'user_id': '72e69531e95b4ec2bd33724873efc884',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:24:09.592184+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'a20c4ffd-fed2-4064-947d-03394cb53abf',
#   'user_name': 'Kiwi',
#   'user_id': '72e69531e95b4ec2bd33724873efc884',
#   'message_type': 'WASON_SUBMIT',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:24:15.074218+00:00',
#   'user_type': 'participant'},
#  {'message_id': '161a554b-1d88-4c34-a6d0-02e91205b8e4',
#   'user_name': 'Hedgehog',
#   'user_id': '3846adbce13f46f987bf284ce3dad593',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:24:23.026730+00:00',
#   'user_type': 'participant'},
#  {'message_id': '3508b764-0211-45c0-ba47-ce95e34d5b32',
#   'user_name': 'Hedgehog',
#   'user_id': '3846adbce13f46f987bf284ce3dad593',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:24:23.807699+00:00',
#   'user_type': 'participant'},
#  {'message_id': '10b7b62b-85d4-460f-af4c-7c8d7f1d4cb5',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': True},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:24:25.460089+00:00',
#   'user_type': 'participant'},
#  {'message_id': '81c2dc9a-2fac-4905-b321-9cee2a8d9949',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_SUBMIT',
#   'content': [{'value': 'G', 'checked': True},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:24:27.291749+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'e9b27044-6486-497a-b3bc-c41ec5e47b0e',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': True},
#    {'value': '2', 'checked': False},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:24:36.267810+00:00',
#   'user_type': 'participant'},
#  {'message_id': '9714ce6d-5156-40e1-8cf1-5f6a55352122',
#   'user_name': 'Hedgehog',
#   'user_id': '3846adbce13f46f987bf284ce3dad593',
#   'message_type': 'WASON_SUBMIT',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:24:50.602999+00:00',
#   'user_type': 'participant'},
#  {'message_id': '686fcd49-97d1-4869-be74-5a396b8d2333',
#   'user_name': 'Bat',
#   'user_id': 'f72989875dbe4a63a214055059ca0fc4',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': True},
#    {'value': '2', 'checked': False},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:25:29.274032+00:00',
#   'user_type': 'participant'},
#  {'message_id': '9cabc666-9456-4e20-9392-34308d1afc67',
#   'user_name': 'Bat',
#   'user_id': 'f72989875dbe4a63a214055059ca0fc4',
#   'message_type': 'WASON_SUBMIT',
#   'content': [{'value': 'G', 'checked': True},
#    {'value': '2', 'checked': False},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:25:30.306076+00:00',
#   'user_type': 'participant'},
#  {'message_id': '03c786cc-5897-491c-827c-0c9b8f076ed7',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': True},
#    {'value': '2', 'checked': False},
#    {'value': '7', 'checked': True},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:25:48.741598+00:00',
#   'user_type': 'participant'},
#  {'message_id': '4acc3d1e-18b9-4784-b154-15a9f88d62f6',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': False},
#    {'value': '7', 'checked': True},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:25:50.165073+00:00',
#   'user_type': 'participant'},
#  {'message_id': '537a66c6-9509-4af6-a7f8-10dec22fda8f',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_SUBMIT',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': False},
#    {'value': '7', 'checked': True},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_ONBOARDING',
#   'timestamp': '2020-08-19 18:25:51.027091+00:00',
#   'user_type': 'participant'},
#  {'message_id': '8b967aa2-8747-4343-9970-9aa50da393bf',
#   'user_name': 'SYSTEM',
#   'user_id': '-1',
#   'message_type': 'FINISHED_ONBOARDING',
#   'content': '7',
#   'user_status': 'UKN',
#   'timestamp': '2020-08-19 18:25:51.397561+00:00',
#   'user_type': 'participant'},
#  {'message_id': '37025a28-8a5a-4a46-9f74-62cf5617f7e9',
#   'user_name': 'Kiwi',
#   'user_id': '72e69531e95b4ec2bd33724873efc884',
#   'message_type': 'CHAT_MESSAGE',
#   'content': 'Hello!',
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:26:17.521410+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'be16fa8c-ec5f-4038-9401-4d180df6cd2b',
#   'user_name': 'Bat',
#   'user_id': 'f72989875dbe4a63a214055059ca0fc4',
#   'message_type': 'CHAT_MESSAGE',
#   'content': 'HELLO',
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:26:26.073005+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'a741dbef-74da-4aa3-8463-d5fda0b92cb9',
#   'user_name': 'Kiwi',
#   'user_id': '72e69531e95b4ec2bd33724873efc884',
#   'message_type': 'CHAT_MESSAGE',
#   'content': 'I think cards 2 and A are correct.',
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:26:37.190087+00:00',
#   'user_type': 'participant'},
#  {'message_id': '91606072-6c87-40f1-8285-32af90b72534',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'CHAT_MESSAGE',
#   'content': '123',
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:26:41.266711+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'd4f098b7-4716-4ca5-88ec-f2333ad405e9',
#   'user_name': 'Bat',
#   'user_id': 'f72989875dbe4a63a214055059ca0fc4',
#   'message_type': 'CHAT_MESSAGE',
#   'content': 'YES',
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:26:54.916342+00:00',
#   'user_type': 'participant'},
#  {'message_id': '7d663923-29bb-47b8-8567-65f4accf2200',
#   'user_name': 'Kiwi',
#   'user_id': '72e69531e95b4ec2bd33724873efc884',
#   'message_type': 'CHAT_MESSAGE',
#   'content': '@Ox what cards do you have?',
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:27:15.806095+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'd83652d7-4e1a-4a9c-a96f-f7ec8b71b6b9',
#   'user_name': 'Hedgehog',
#   'user_id': '3846adbce13f46f987bf284ce3dad593',
#   'message_type': 'CHAT_MESSAGE',
#   'content': '2 and A is what I think',
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:27:20.341228+00:00',
#   'user_type': 'participant'},
#  {'message_id': '127df11e-ff56-4a81-934e-07edbafa6c76',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': True},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:27:35.444780+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'e89469c4-4a57-4bdd-8009-9dc859b6a4a8',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:27:36.819748+00:00',
#   'user_type': 'participant'},
#  {'message_id': '51270780-6ab6-4ba2-950e-fdbfaba8d093',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_SUBMIT',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:27:37.352017+00:00',
#   'user_type': 'participant'},
#  {'message_id': '82b8fa6b-9e5f-48de-9be5-e173a1b7b74b',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'CHAT_MESSAGE',
#   'content': '2',
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:27:40.195723+00:00',
#   'user_type': 'participant'},
#  {'message_id': '13ac4bc3-d26b-4c4d-87f3-00f559d85a18',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:27:50.137550+00:00',
#   'user_type': 'participant'},
#  {'message_id': '1f9e985c-6478-467e-945f-75a9eff784fd',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_SUBMIT',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:27:51.878974+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'd02b16fe-867f-4375-b7f8-b6b3a24d5bc4',
#   'user_name': 'Bat',
#   'user_id': 'f72989875dbe4a63a214055059ca0fc4',
#   'message_type': 'CHAT_MESSAGE',
#   'content': 'I THINK 7',
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:28:07.079080+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'cb490916-cd7d-4ebd-9007-5ab4032a9e7c',
#   'user_name': 'Kiwi',
#   'user_id': '72e69531e95b4ec2bd33724873efc884',
#   'message_type': 'CHAT_MESSAGE',
#   'content': 'There are 4 cards, @Ox ',
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:28:09.369382+00:00',
#   'user_type': 'participant'},
#  {'message_id': '6ce06e30-f596-472c-8a5f-5685e1df9216',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': False},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:28:22.636666+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'b1fceb1b-a85c-4d39-8b4f-0fc7ea7d0453',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': False},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:28:24.479150+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'c8b2521d-57f7-41e8-9861-ce1b7bea1f93',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': False},
#    {'value': '7', 'checked': True},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:28:26.336732+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'fe8a0e82-534b-4c85-a2a8-1e949414100e',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_SUBMIT',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': False},
#    {'value': '7', 'checked': True},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:28:27.337479+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'ed080c9a-a1d1-4f52-9b3c-a885dce516b5',
#   'user_name': 'Bat',
#   'user_id': 'f72989875dbe4a63a214055059ca0fc4',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': True},
#    {'value': '2', 'checked': False},
#    {'value': '7', 'checked': True},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:28:37.783847+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'e8aebf8f-b2f8-40a2-8906-b9dbf37d29ca',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': True},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:28:42.922922+00:00',
#   'user_type': 'participant'},
#  {'message_id': '50e28bb0-f9bf-4a59-9446-af4e1ea6b522',
#   'user_name': 'Kiwi',
#   'user_id': '72e69531e95b4ec2bd33724873efc884',
#   'message_type': 'CHAT_MESSAGE',
#   'content': '7 is an odd number.',
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:28:43.364793+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'e0f61e5c-42b1-4f98-9dfb-41caced8dd14',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_SUBMIT',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': True},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:28:45.485440+00:00',
#   'user_type': 'participant'},
#  {'message_id': '43bf5297-c7a7-4019-a479-3f6434edef5d',
#   'user_name': 'Kiwi',
#   'user_id': '72e69531e95b4ec2bd33724873efc884',
#   'message_type': 'CHAT_MESSAGE',
#   'content': 'not even',
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:28:48.550373+00:00',
#   'user_type': 'participant'},
#  {'message_id': '5fc168c2-8524-4204-8ca4-db95dfbb37a3',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'CHAT_MESSAGE',
#   'content': 'HAI',
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:29:08.442891+00:00',
#   'user_type': 'participant'},
#  {'message_id': '5d7ff9df-3335-423c-81d7-6540599c5668',
#   'user_name': 'Bat',
#   'user_id': 'f72989875dbe4a63a214055059ca0fc4',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': True},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': True},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:30:15.844934+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'f31411bf-2816-4373-ba84-f943450b983f',
#   'user_name': 'Bat',
#   'user_id': 'f72989875dbe4a63a214055059ca0fc4',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': True},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:30:17.032792+00:00',
#   'user_type': 'participant'},
#  {'message_id': '87fe9834-4fd5-4ac6-b59c-2cfb76e53834',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'CHAT_MESSAGE',
#   'content': 'G',
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:30:27.594234+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'b0bddcc2-919b-464e-b0f7-9703f72d9e15',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'CHAT_MESSAGE',
#   'content': 'GA ',
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:30:34.726923+00:00',
#   'user_type': 'participant'},
#  {'message_id': '721d8663-2647-49cb-aa07-471bbae0c004',
#   'user_name': 'Bat',
#   'user_id': 'f72989875dbe4a63a214055059ca0fc4',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': True},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': True},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:30:34.933266+00:00',
#   'user_type': 'participant'},
#  {'message_id': '7c3c388d-1353-4a00-a005-907db7efe172',
#   'user_name': 'Bat',
#   'user_id': 'f72989875dbe4a63a214055059ca0fc4',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': True},
#    {'value': '2', 'checked': False},
#    {'value': '7', 'checked': True},
#    {'value': 'A', 'checked': False}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:30:37.209192+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'ac51bdae-57ed-4b6f-bf32-d3b617b22601',
#   'user_name': 'Kiwi',
#   'user_id': '72e69531e95b4ec2bd33724873efc884',
#   'message_type': 'CHAT_MESSAGE',
#   'content': "G is not a vowel so it's not a good answer.",
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:31:01.708191+00:00',
#   'user_type': 'participant'},
#  {'message_id': '35581b92-c29d-422c-92ad-dd41bdfe2fcd',
#   'user_name': 'Kiwi',
#   'user_id': '72e69531e95b4ec2bd33724873efc884',
#   'message_type': 'CHAT_MESSAGE',
#   'content': "2 is an even number so it's correct",
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:31:11.892519+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'df9139cb-0e89-486d-9c22-467e16d96a74',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': True},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:31:15.399534+00:00',
#   'user_type': 'participant'},
#  {'message_id': '62c03b0c-fb56-48f9-b225-ce1a2e72d828',
#   'user_name': 'Bat',
#   'user_id': 'f72989875dbe4a63a214055059ca0fc4',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': True},
#    {'value': '2', 'checked': False},
#    {'value': '7', 'checked': True},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:31:19.563080+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'd191277a-6ae3-4ae7-bc9c-9a5a7ce3b139',
#   'user_name': 'Bat',
#   'user_id': 'f72989875dbe4a63a214055059ca0fc4',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': True},
#    {'value': '2', 'checked': False},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:31:20.328271+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'e7510e5b-5713-4da1-bef7-fc696c102b9d',
#   'user_name': 'Bat',
#   'user_id': 'f72989875dbe4a63a214055059ca0fc4',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': False},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:31:21.018579+00:00',
#   'user_type': 'participant'},
#  {'message_id': '793ac2fd-51f8-40aa-86f7-074db7baeffe',
#   'user_name': 'Bat',
#   'user_id': 'f72989875dbe4a63a214055059ca0fc4',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:31:21.658848+00:00',
#   'user_type': 'participant'},
#  {'message_id': '58defd7c-2cc0-4a89-b4da-dc38ffdca944',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': False},
#    {'value': '7', 'checked': True},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:31:21.802170+00:00',
#   'user_type': 'participant'},
#  {'message_id': '0cd4c1f8-3750-4ae7-bafa-3889e9663b3b',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': True},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:31:21.841650+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'd98ff8c5-2319-4285-b646-9c59042c907f',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': False},
#    {'value': '7', 'checked': True},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:31:25.190445+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'a37c6fdc-6e5e-48d2-8d79-67a1e8925250',
#   'user_name': 'AUTO_KICKED',
#   'user_id': '3846adbce13f46f987bf284ce3dad593',
#   'message_type': 'LEAVE_ROOM',
#   'content': '',
#   'user_status': 'AUTO_KICKED',
#   'timestamp': '2020-08-19 18:31:25.566872+00:00',
#   'user_type': 'participant'},
#  {'message_id': '8fd1a0d5-8868-4f47-84b1-c857dfa57cec',
#   'user_name': 'Kiwi',
#   'user_id': '72e69531e95b4ec2bd33724873efc884',
#   'message_type': 'CHAT_MESSAGE',
#   'content': '7 is not even',
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:31:28.029512+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'e01c6ef9-29f4-43a5-888d-2338b936363a',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': True},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:31:31.159723+00:00',
#   'user_type': 'participant'},
#  {'message_id': '8e442a11-193b-4ccf-a57a-2c9309f5efd9',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:31:32.727739+00:00',
#   'user_type': 'participant'},
#  {'message_id': '05436bd4-098b-433b-a4d0-eaaa7b1adb08',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': True},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:31:32.912594+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'c93bc629-3d1d-4f9d-ab75-5e989238b7ef',
#   'user_name': 'Kiwi',
#   'user_id': '72e69531e95b4ec2bd33724873efc884',
#   'message_type': 'CHAT_MESSAGE',
#   'content': 'A is a vowel',
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:31:33.051109+00:00',
#   'user_type': 'participant'},
#  {'message_id': '43e6fe54-229a-48c2-8215-80145efedb2d',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_GAME',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:31:33.808569+00:00',
#   'user_type': 'participant'},
#  {'message_id': '7f7bb4ea-2130-40cb-bbf5-acc34da09c33',
#   'user_name': 'Ox',
#   'user_id': '4f3242c6e1ec42a3aa43e12765095f92',
#   'message_type': 'WASON_SUBMIT',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:31:38.799851+00:00',
#   'user_type': 'participant'},
#  {'message_id': '8cf9f11f-a0b7-4b2c-9c4e-3abf979f9b62',
#   'user_name': 'Kiwi',
#   'user_id': '72e69531e95b4ec2bd33724873efc884',
#   'message_type': 'CHAT_MESSAGE',
#   'content': 'so just 2 and A',
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:31:39.995500+00:00',
#   'user_type': 'participant'},
#  {'message_id': '9e7400e3-a4fd-421b-a80d-6470e61937d8',
#   'user_name': 'Bat',
#   'user_id': 'f72989875dbe4a63a214055059ca0fc4',
#   'message_type': 'CHAT_MESSAGE',
#   'content': 'I SUBMIT 2 AND  A',
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:31:53.532653+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'ab5d0537-3c37-4b79-8b64-065da8b6808d',
#   'user_name': 'Kiwi',
#   'user_id': '72e69531e95b4ec2bd33724873efc884',
#   'message_type': 'CHAT_MESSAGE',
#   'content': 'me too',
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:32:02.911924+00:00',
#   'user_type': 'participant'},
#  {'message_id': '8edf5a94-7e8e-4c04-b506-88e06bb412cc',
#   'user_name': 'Bat',
#   'user_id': 'f72989875dbe4a63a214055059ca0fc4',
#   'message_type': 'OUT_OF_TIME',
#   'content': "[{'value': 'G', 'checked': False}, {'value': '2', 'checked': True}, {'value': '7', 'checked': False}, {'value': 'A', 'checked': True}]",
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:32:51.535811+00:00',
#   'user_type': 'participant'},
#  {'message_id': '82ccb056-a237-4b19-8f39-553b3f388b14',
#   'user_name': 'Kiwi',
#   'user_id': '72e69531e95b4ec2bd33724873efc884',
#   'message_type': 'OUT_OF_TIME',
#   'content': "[{'value': 'G', 'checked': False}, {'value': '2', 'checked': True}, {'value': '7', 'checked': False}, {'value': 'A', 'checked': True}]",
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:32:51.746553+00:00',
#   'user_type': 'participant'},
#  {'message_id': '5209d8b8-b2b3-4f20-aee7-596ce13bcabf',
#   'user_name': 'Bat',
#   'user_id': 'f72989875dbe4a63a214055059ca0fc4',
#   'message_type': 'WASON_SUBMIT',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:33:07.007448+00:00',
#   'user_type': 'participant'},
#  {'message_id': '1c2e18c9-c308-451e-9cb4-ce1f05216d0a',
#   'user_name': 'Kiwi',
#   'user_id': '72e69531e95b4ec2bd33724873efc884',
#   'message_type': 'WASON_SUBMIT',
#   'content': [{'value': 'G', 'checked': False},
#    {'value': '2', 'checked': True},
#    {'value': '7', 'checked': False},
#    {'value': 'A', 'checked': True}],
#   'user_status': 'USR_PLAYING',
#   'timestamp': '2020-08-19 18:33:22.494687+00:00',
#   'user_type': 'participant'},
#  {'message_id': 'c937dca7-8898-42ad-b687-82f8b2496928',
#   'user_name': 'SYSTEM',
#   'user_id': '-1',
#   'message_type': 'WASON_FINISHED',
#   'content': '',
#   'user_status': 'UKN',
#   'timestamp': '2020-08-19 18:33:22.928380+00:00',
#   'user_type': 'participant'}]

# %%
allowed = {
    'vowels': {'A', 'O', 'U', 'E', 'I', 'Y'},
    'consonants': {'B', 'C', 'D', 'F', 'G', 'H', 'J', 'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'X', 'Z', 'W'},
    'odds': {'1', '3', '5', '7', '9'},
    'evens': {'0', '2', '4', '6', '8'}
}
def process_solution(solution):
    res = set()
    for item in solution:
        for a_k, a_v in allowed.items():
            if item['checked'] and item['value'] in a_v:
                res.update(a_k[0])
    return res

# %%
def process_conversation(conversation):
    user_map = defaultdict(lambda: [])
    conversation_map = []
    for item in conversation:
        if item['message_type'] == 'WASON_SUBMIT':
            if item['user_status'] == 'USR_ONBOARDING':
                user_map[item['user_name']] = [process_solution(item['content'])]
            else:
                user_map[item['user_name']].append(process_solution(item['content']))
                conversation_map.append(process_solution(item['content']))
    return user_map, conversation_map

# %%
all_conv_stats_per_user = []
all_conv_stats_per_game = []

for item in raw_data:
    user, conv_m = process_conversation(item.raw_db_conversation)
    all_conv_stats_per_user.append(user)
    all_conv_stats_per_game.append(conv_m)

# %%
total_submissions = 0
total_users = 0
total_convs = 0
for item in all_conv_stats_per_user:
    total_convs += 1
    total_users += len(item)
    for subm in item:
        total_submissions += len(subm)

# %%
total_submissions / total_users
# Out:
# 5.475

# %%
total_submissions / total_convs
# Out:
# 17.139130434782608

# %%
len([a for s in all_conv_stats_per_game for a in s]) / len(all_conv_stats_per_game)
# Out:
# 3.121739130434783

# %% [markdown]
# ## Calculate probabilities

# %%
from collections import Counter

# %%
# BIGRAMS - per user submissions

# %%
prob_counter = Counter()
total_pairs = 0
for conv in all_conv_stats_per_user:
    for user, elements in conv.items():
        els = ["".join(e) for e in elements]
        processed = ['BEGIN', *els, "END"]
        for pr, current in zip(processed[:-1], processed[1:]):
            total_pairs += 1
            prob_counter.update(["{}->{}".format(pr, current)])

# %%
prob_counter.most_common(50)
# Out:
# [('BEGIN->ev', 119),
#  ('ev->END', 119),
#  ('ov->END', 107),
#  ('BEGIN->v', 68),
#  ('v->END', 62),
#  ('ev->ev', 53),
#  ('BEGIN->ov', 41),
#  ('ov->ov', 33),
#  ('v->v', 28),
#  ('v->ev', 24),
#  ('ev->ov', 22),
#  ('eov->END', 22),
#  ('BEGIN->c', 16),
#  ('BEGIN->eov', 16),
#  ('ev->v', 15),
#  ('BEGIN->e', 15),
#  ('v->ov', 14),
#  ('BEGIN->eocv', 12),
#  ('eocv->END', 12),
#  ('BEGIN->ec', 11),
#  ('BEGIN->o', 11),
#  ('eov->ov', 11),
#  ('ev->eov', 9),
#  ('BEGIN->co', 9),
#  ('e->END', 9),
#  ('BEGIN->oecv', 8),
#  ('e->ev', 8),
#  ('c->ev', 8),
#  ('BEGIN->cv', 8),
#  ('BEGIN->eo', 6),
#  ('ec->END', 5),
#  ('ocev->END', 5),
#  ('ec->ov', 4),
#  ('eocv->ev', 4),
#  ('eov->eov', 4),
#  ('ev->ocev', 4),
#  ('oecv->ov', 4),
#  ('c->v', 4),
#  ('BEGIN->', 4),
#  ('->v', 4),
#  ('ov->ev', 4),
#  ('e->e', 4),
#  ('ev->eocv', 4),
#  ('cv->ev', 4),
#  ('ec->v', 3),
#  ('cv->v', 3),
#  ('eocv->eocv', 3),
#  ('o->ov', 3),
#  ('BEGIN->ecv', 3),
#  ('co->END', 3)]

# %%
# Bigrams - per game submissions

# %%
all_conv_stats_per_game
# Out:
# [[{'o', 'v'}],
#  [{'o', 'v'}, {'o', 'v'}],
#  [{'v'}, {'e', 'v'}, {'e', 'v'}, {'v'}, {'v'}, {'v'}],
#  [{'e'}, {'e', 'v'}, {'o'}, {'e', 'o'}, {'e', 'v'}, {'e', 'v'}, {'e', 'v'}],
#  [{'v'}, {'v'}, {'v'}],
#  [{'v'}, {'o', 'v'}, {'o', 'v'}],
#  [{'e', 'v'}, {'e', 'v'}, {'e', 'v'}],
#  [{'o', 'v'}, {'o', 'v'}, {'o', 'v'}],
#  [{'c', 'e', 'o', 'v'}, {'e', 'o', 'v'}, {'e', 'o', 'v'}, {'e', 'o', 'v'}],
#  [{'e', 'o', 'v'}, {'e', 'o', 'v'}],
#  [{'o', 'v'}, {'o', 'v'}, {'o', 'v'}, {'o', 'v'}],
#  [{'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'}],
#  [{'o', 'v'}, {'o', 'v'}, {'o', 'v'}, {'o', 'v'}],
#  [{'o', 'v'}, {'o', 'v'}, {'o', 'v'}],
#  [{'v'}, {'v'}, {'v'}],
#  [{'v'}, {'v'}, {'v'}],
#  [{'e', 'o', 'v'}, {'e', 'o', 'v'}, {'e', 'o', 'v'}],
#  [{'v'}, {'v'}, {'v'}],
#  [{'o', 'v'}, {'o', 'v'}],
#  [{'e', 'v'}, {'e', 'v'}, {'e', 'v'}, {'e', 'v'}],
#  [{'e', 'v'}, {'e', 'v'}],
#  [{'c', 'e', 'o', 'v'}, {'e', 'o', 'v'}, {'c', 'e', 'o', 'v'}],
#  [{'e', 'v'}, {'e', 'v'}, {'e', 'v'}],
#  [{'v'}, {'v'}, {'v'}],
#  [{'o', 'v'}, {'o', 'v'}],
#  [{'e'}, {'e', 'v'}, {'e', 'v'}],
#  [{'v'}, {'v'}, {'v'}],
#  [{'e', 'v'}, {'o', 'v'}, {'o', 'v'}],
#  [{'e'}, {'e', 'v'}, {'o', 'v'}, {'o', 'v'}, {'o', 'v'}],
#  [{'v'}, {'e', 'v'}],
#  [{'o', 'v'}, {'o', 'v'}, {'c', 'e', 'o', 'v'}, {'e', 'v'}],
#  [{'e', 'o', 'v'}, {'e', 'o', 'v'}, {'e', 'o', 'v'}],
#  [{'e', 'v'}, {'o', 'v'}, {'e', 'v'}],
#  [{'o', 'v'}, {'o', 'v'}, {'o', 'v'}],
#  [{'o', 'v'}, {'o', 'v'}, {'o', 'v'}],
#  [{'e', 'v'}, {'e', 'v'}, {'e', 'v'}],
#  [{'v'}, {'o', 'v'}, {'o', 'v'}, {'o', 'v'}],
#  [{'e', 'v'}, {'v'}],
#  [{'e', 'o'}, {'e', 'o', 'v'}, {'e', 'v'}, {'e', 'v'}],
#  [{'v'}, {'v'}, {'v'}],
#  [{'e', 'v'}, {'e', 'v'}, {'v'}],
#  [{'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'}],
#  [{'v'}, {'c', 'e', 'o'}, {'v'}],
#  [{'e', 'v'}, {'o', 'v'}, {'e', 'v'}, {'e', 'v'}],
#  [{'o', 'v'}, {'e', 'o', 'v'}, {'o', 'v'}, {'o', 'v'}],
#  [{'v'}, {'v'}, {'v'}],
#  [{'e', 'v'}, {'c', 'e', 'o', 'v'}, {'c', 'e', 'o', 'v'}],
#  [{'o', 'v'}, {'o', 'v'}, {'o', 'v'}],
#  [{'e', 'v'}, {'v'}, {'e', 'v'}, {'c', 'e', 'o', 'v'}, {'c', 'e', 'o', 'v'}],
#  [{'e', 'v'}, {'o', 'v'}, {'o', 'v'}],
#  [{'e', 'v'}, {'e', 'v'}, {'e', 'v'}, {'e', 'v'}],
#  [{'e', 'o', 'v'}, {'o', 'v'}, {'e', 'v'}, {'o', 'v'}],
#  [{'o', 'v'}],
#  [{'e'}, {'e', 'v'}, {'e', 'v'}],
#  [{'c', 'e'}, {'c', 'e'}, {'c', 'e'}],
#  [{'o', 'v'}, {'o', 'v'}],
#  [{'v'}, {'v'}, {'e', 'v'}, {'v'}],
#  [{'c', 'o'}],
#  [{'e'}, {'v'}, {'v'}, {'v'}],
#  [{'e', 'v'}],
#  [{'v'}, {'e', 'v'}, {'e', 'v'}, {'e', 'v'}],
#  [{'o', 'v'}, {'o', 'v'}],
#  [{'e', 'o'}],
#  [{'v'}, {'v'}],
#  [{'v'}, {'v'}],
#  [{'e'}, {'e', 'v'}],
#  [{'o', 'v'}, {'o', 'v'}, {'v'}],
#  [{'o', 'v'}, {'o', 'v'}],
#  [{'o', 'v'}, {'o', 'v'}, {'o', 'v'}],
#  [{'o', 'v'}, {'o', 'v'}, {'o', 'v'}],
#  [{'v'}, {'e', 'v'}],
#  [{'o', 'v'}, {'o', 'v'}],
#  [{'e', 'v'}, {'e', 'v'}],
#  [{'e', 'v'}, {'e', 'v'}, {'e', 'v'}],
#  [{'c', 'v'}, {'e', 'v'}, {'e', 'v'}, {'e', 'v'}],
#  [{'o', 'v'}, {'o', 'v'}],
#  [{'e', 'v'}, {'e', 'v'}, {'e', 'v'}],
#  [{'e'}, {'v'}, {'o'}, {'c'}, {'e', 'v'}, {'e', 'v'}, {'e', 'v'}, {'e', 'v'}],
#  [{'e', 'v'}, {'e', 'v'}, {'e', 'v'}],
#  [{'v'}, {'v'}, {'e', 'v'}, {'e', 'v'}, {'e', 'v'}],
#  [{'e', 'v'}, {'e', 'v'}],
#  [{'o', 'v'}, {'o', 'v'}, {'o', 'v'}],
#  [{'o', 'v'}, {'o', 'v'}, {'o', 'v'}, {'o', 'v'}],
#  [{'v'}, {'v'}, {'v'}],
#  [{'e', 'v'}, {'v'}, {'e', 'v'}, {'o', 'v'}, {'v'}, {'o', 'v'}],
#  [{'e', 'v'}, {'e', 'v'}, {'e', 'v'}],
#  [{'e', 'v'}, {'o', 'v'}, {'o', 'v'}, {'o', 'v'}],
#  [{'v'}, {'v'}, {'v'}],
#  [{'o', 'v'}, {'o', 'v'}, {'o', 'v'}],
#  [{'e', 'v'}, {'e', 'v'}, {'e', 'v'}, {'c', 'e', 'o', 'v'}],
#  [{'e', 'v'}, {'e', 'v'}, {'e', 'v'}],
#  [{'e', 'v'}, {'c', 'e'}, {'e'}, {'o', 'v'}],
#  [{'o', 'v'}, {'c', 'o'}],
#  [{'e', 'v'}, {'e', 'v'}, {'e', 'v'}],
#  [{'e'}, {'e'}],
#  [{'c', 'e', 'o', 'v'}, {'v'}, {'o', 'v'}],
#  [{'o', 'v'}, {'o', 'v'}],
#  [{'v'},
#   {'v'},
#   {'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'o'},
#   {'c', 'o'},
#   {'o', 'v'}],
#  [{'c', 'e', 'o', 'v'}, {'o', 'v'}],
#  [{'e', 'v'}, {'e', 'o', 'v'}, {'e', 'v'}, {'e', 'v'}],
#  [],
#  [{'e', 'v'}, {'e', 'v'}],
#  [{'o', 'v'}, {'o', 'v'}, {'o', 'v'}],
#  [{'c', 'e', 'o', 'v'}, {'c', 'e', 'o', 'v'}, {'c', 'e', 'o', 'v'}],
#  [{'c', 'v'}, {'v'}, {'o', 'v'}],
#  [{'c', 'e', 'v'}],
#  [{'v'}, {'o', 'v'}, {'o', 'v'}],
#  [{'o', 'v'}, {'o', 'v'}, {'o', 'v'}],
#  [{'o', 'v'}, {'o', 'v'}, {'o', 'v'}],
#  [{'e', 'v'}, {'e', 'v'}, {'e', 'v'}, {'e'}],
#  [{'e', 'v'}, {'e', 'v'}],
#  [{'e', 'o', 'v'}, {'e', 'o', 'v'}, {'e', 'o', 'v'}, {'e', 'o', 'v'}],
#  [{'e', 'v'}, {'e', 'o', 'v'}, {'e', 'o', 'v'}],
#  [{'e', 'v'}, {'e', 'v'}, {'e', 'v'}],
#  [{'o', 'v'}, {'e', 'v'}]]

# %%
prob_counter_per_game = Counter()
total_pairs_per_game = 0
for conv in all_conv_stats_per_game:
    els = ["".join(e) for e in conv]
    processed = ['BEGIN', *els, "END"]
    for pr, current in zip(processed[:-1], processed[1:]):
        total_pairs += 1
        prob_counter_per_game.update(["{}->{}".format(pr, current)])

# %%
prob_counter_per_game.most_common(30)
# Out:
# [('ov->ov', 55),
#  ('ev->ev', 55),
#  ('ov->END', 41),
#  ('ev->END', 34),
#  ('BEGIN->ev', 34),
#  ('BEGIN->ov', 31),
#  ('v->v', 30),
#  ('BEGIN->v', 23),
#  ('v->END', 19),
#  ('eov->eov', 11),
#  ('v->ev', 10),
#  ('BEGIN->e', 8),
#  ('ev->ov', 8),
#  ('ev->v', 7),
#  ('v->ov', 6),
#  ('eov->END', 6),
#  ('BEGIN->eov', 6),
#  ('eocv->eocv', 6),
#  ('e->ev', 5),
#  ('ov->ev', 4),
#  ('ocev->ocev', 3),
#  ('eocv->END', 3),
#  ('BEGIN->coev', 2),
#  ('coev->eov', 2),
#  ('ev->ocev', 2),
#  ('ocev->END', 2),
#  ('BEGIN->eo', 2),
#  ('eov->ev', 2),
#  ('eov->ov', 2),
#  ('ec->ec', 2)]

# %%
# Trigrams per user:

# %%
prob_counter_trigrams = Counter()
total_triples = 0
for conv in all_conv_stats_per_user:
    for user, elements in conv.items():
        els = ["".join(e) for e in elements]
        processed = ['BEGIN', *els, "END"]
        for pr, current, next_ in zip(processed[:-2], processed[1:-1], processed[2:]):
            total_triples += 1
            prob_counter_trigrams.update(["{}->{}->{}".format(pr, current, next_)])

# %%
prob_counter_trigrams.most_common(50)
# Out:
# [('BEGIN->ev->ev', 51),
#  ('ev->ev->END', 50),
#  ('ov->ov->END', 32),
#  ('BEGIN->ov->ov', 29),
#  ('BEGIN->v->v', 24),
#  ('ev->ov->END', 22),
#  ('v->v->END', 22),
#  ('v->ev->END', 20),
#  ('BEGIN->ev->END', 19),
#  ('BEGIN->ev->ov', 19),
#  ('BEGIN->v->ev', 15),
#  ('v->ov->END', 12),
#  ('BEGIN->v->ov', 12),
#  ('ev->v->END', 11),
#  ('BEGIN->v->END', 11),
#  ('BEGIN->ev->v', 11),
#  ('eov->ov->END', 11),
#  ('BEGIN->eov->ov', 10),
#  ('c->ev->END', 8),
#  ('BEGIN->ev->eov', 8),
#  ('BEGIN->c->ev', 7),
#  ('ev->eov->END', 7),
#  ('BEGIN->ov->END', 6),
#  ('BEGIN->ec->ov', 4),
#  ('ec->ov->END', 4),
#  ('BEGIN->eocv->ev', 4),
#  ('BEGIN->eov->eov', 4),
#  ('BEGIN->e->ev', 4),
#  ('ev->ocev->END', 4),
#  ('BEGIN->oecv->ov', 4),
#  ('oecv->ov->END', 4),
#  ('BEGIN->c->v', 4),
#  ('BEGIN->->v', 4),
#  ('e->ev->END', 4),
#  ('BEGIN->ov->ev', 4),
#  ('ov->ev->END', 4),
#  ('BEGIN->e->e', 4),
#  ('BEGIN->e->END', 4),
#  ('ev->eocv->END', 4),
#  ('BEGIN->ec->v', 3),
#  ('ec->v->END', 3),
#  ('eocv->ev->END', 3),
#  ('eov->eov->END', 3),
#  ('c->v->END', 3),
#  ('cv->v->END', 3),
#  ('eocv->eocv->END', 3),
#  ('BEGIN->o->ov', 3),
#  ('o->ov->END', 3),
#  ('BEGIN->ev->eocv', 3),
#  ('v->v->ev', 3)]

# %%
#Trigrams per game:

# %%
prob_counter_per_game_tri = Counter()
total_pairs_per_game_tri = 0
for conv in all_conv_stats_per_game:
    els = ["".join(e) for e in conv]
    processed = ['BEGIN', *els, "END"]
    for pr, current, next_ in zip(processed[:-2], processed[1:-1], processed[2:]):
        total_pairs += 1
        prob_counter_per_game_tri.update(["{}->{}->{}".format(pr, current, next_)])

# %%
prob_counter_per_game_tri.most_common(50)
# Out:
# [('ov->ov->END', 32),
#  ('ev->ev->END', 27),
#  ('BEGIN->ov->ov', 26),
#  ('ev->ev->ev', 23),
#  ('ov->ov->ov', 21),
#  ('BEGIN->ev->ev', 20),
#  ('BEGIN->v->v', 15),
#  ('v->v->END', 14),
#  ('v->v->v', 13),
#  ('eov->eov->END', 6),
#  ('BEGIN->e->ev', 5),
#  ('eov->eov->eov', 5),
#  ('BEGIN->ev->ov', 5),
#  ('BEGIN->v->ev', 4),
#  ('v->ev->ev', 4),
#  ('BEGIN->eov->eov', 4),
#  ('ev->ov->ov', 4),
#  ('BEGIN->v->ov', 3),
#  ('v->ov->ov', 3),
#  ('BEGIN->ev->v', 3),
#  ('ev->v->END', 3),
#  ('eocv->eocv->eocv', 3),
#  ('eocv->eocv->END', 3),
#  ('ev->v->ev', 3),
#  ('v->v->ev', 3),
#  ('v->ov->END', 3),
#  ('BEGIN->ov->END', 2),
#  ('ev->ev->v', 2),
#  ('BEGIN->coev->eov', 2),
#  ('ev->ocev->ocev', 2),
#  ('ocev->ocev->END', 2),
#  ('e->ev->ev', 2),
#  ('v->ev->END', 2),
#  ('ev->ov->ev', 2),
#  ('ov->ev->END', 2),
#  ('eov->ev->ev', 2),
#  ('v->ev->v', 2),
#  ('BEGIN->e->v', 2),
#  ('BEGIN->ev->eov', 2),
#  ('ev->v->v', 1),
#  ('e->ev->o', 1),
#  ('ev->o->eo', 1),
#  ('o->eo->ev', 1),
#  ('eo->ev->ev', 1),
#  ('coev->eov->eov', 1),
#  ('BEGIN->ev->ocev', 1),
#  ('ocev->ocev->ocev', 1),
#  ('coev->eov->coev', 1),
#  ('eov->coev->END', 1),
#  ('e->ev->ov', 1)]

# %% [markdown]
# # Solution Tracker

# %%
from featurisers.raw_wason_featuriser import calculate_stats, preprocess_conversation_dump
from solution_tracker.augment_with_solution import merge_with_solution_raw, merge_with_solution_annotation_message_level

# %%
nlp = spacy.load("en_core_web_sm")

# %%
def process_solution_simple(solution):
    res = set()
    for item in solution:
        for a_k, a_v in allowed.items():
            if item in a_v:
                res.update(a_k[0])
    return res

# %%
# Out:
# {'o', 'v'}

# %%
solutions_per_dialogue = []
for item in raw_data:
    prepr = preprocess_conversation_dump(item.raw_db_conversation)    
    item.wason_messages_from_raw()
    item.preprocess_everything(nlp)
    agreement_predictor = Predictor('models/agreement.pkl')
    sol_tracker = solution_tracker(item, False, agreement_predictor)
    
    res = []
    for m in sol_tracker:
        res.append(process_solution_simple(m['value']))
    solutions_per_dialogue.append(res)

# %%
solutions_per_dialogue
# Out:
# [[{'o', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'o', 'v'},
#   {'v'},
#   {'o'},
#   {'e'},
#   {'c'},
#   {'o', 'v'}],
#  [{'o', 'v'},
#   {'c', 'e'},
#   {'e', 'v'},
#   {'c', 'e'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'e'},
#   {'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e'},
#   {'e'},
#   {'o'},
#   {'c'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'v'},
#   {'v'}],
#  [{'e', 'v'},
#   {'o'},
#   {'e', 'v'},
#   {'c'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e'},
#   {'e'},
#   {'e', 'v'},
#   {'o'},
#   {'o'},
#   {'o'},
#   {'e', 'o'},
#   {'c'},
#   {'c', 'v'},
#   {'e'},
#   {'o'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'}],
#  [{'c', 'e', 'o', 'v'},
#   {'c', 'e'},
#   {'v'},
#   {'c', 'e'},
#   {'v'},
#   {'e', 'v'},
#   {'c', 'e', 'v'},
#   {'e'},
#   {'c', 'e'},
#   {'o', 'v'},
#   {'v'},
#   {'v'},
#   {'e'},
#   {'e'},
#   {'c', 'e'},
#   {'e', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'v'}],
#  [{'e', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'v'},
#   {'e', 'v'},
#   {'o'},
#   {'e'},
#   {'o'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'v'},
#   {'c'},
#   {'c', 'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c', 'o'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c', 'o'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'}],
#  [{'e', 'v'},
#   {'c', 'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'c', 'o', 'v'},
#   {'o', 'v'},
#   {'c'},
#   {'o', 'v'},
#   {'c'},
#   {'c'},
#   {'o', 'v'},
#   {'o'},
#   {'c', 'e', 'o', 'v'},
#   {'o'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'c', 'e', 'o', 'v'},
#   {'e', 'o'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'o'},
#   {'e', 'o'},
#   {'e', 'o', 'v'},
#   {'e', 'o'},
#   {'v'},
#   {'v'},
#   {'o'},
#   {'o'},
#   {'o'},
#   {'c'},
#   {'e'},
#   {'c'},
#   {'e', 'o', 'v'},
#   {'c'},
#   {'e', 'o'},
#   {'v'},
#   {'o'},
#   {'o'},
#   {'v'},
#   {'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'e', 'o', 'v'}],
#  [{'e', 'o', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'o', 'v'},
#   {'o'},
#   {'o'},
#   {'e', 'o', 'v'},
#   {'c', 'o'},
#   {'e', 'o', 'v'},
#   {'c'},
#   {'e', 'o', 'v'},
#   {'e', 'o', 'v'}],
#  [{'e', 'v'},
#   {'o', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'v'},
#   {'o', 'v'}],
#  [{'e'},
#   {'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'o'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'}],
#  [{'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e'},
#   {'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'e'},
#   {'o', 'v'},
#   {'e'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'e'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'v'},
#   {'e'},
#   {'e'},
#   {'v'},
#   {'v'},
#   {'o'},
#   {'o'},
#   {'o', 'v'},
#   {'c', 'e'},
#   {'o'},
#   {'e'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'v'},
#   {'v'},
#   {'c'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c'},
#   {'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'}],
#  [{'v'},
#   {'o'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'v'}],
#  [{'e', 'v'},
#   {'e', 'v'},
#   {'c', 'e'},
#   {'e'},
#   {'e'},
#   {'v'},
#   {'e', 'v'},
#   {'c'},
#   {'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c'},
#   {'c', 'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c'},
#   {'o'},
#   {'v'},
#   {'o'},
#   {'e'},
#   {'v'},
#   {'e', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'e', 'o', 'v'}],
#  [set(),
#   {'c', 'e', 'o', 'v'},
#   {'c', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'}],
#  [{'v'},
#   {'e', 'v'},
#   {'o', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'o', 'v'},
#   {'o'},
#   {'c', 'e', 'o', 'v'},
#   {'e'},
#   {'c'},
#   {'c'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'c', 'o'},
#   {'e'},
#   {'c'},
#   {'e', 'v'},
#   {'c'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'}],
#  [{'e', 'v'}, {'v'}, {'e', 'v'}, {'c', 'e', 'o', 'v'}, {'e', 'v'}],
#  [{'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c'},
#   {'c', 'o'},
#   {'v'},
#   {'v'},
#   {'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'}],
#  [{'e', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'}],
#  [{'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'o'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'}],
#  [{'o', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'o', 'v'},
#   {'c', 'o', 'v'},
#   {'c', 'o'},
#   {'o', 'v'},
#   {'c', 'v'},
#   {'v'},
#   {'e'},
#   {'v'},
#   {'v'},
#   {'o', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'e', 'v'},
#   {'o'},
#   {'e', 'v'},
#   {'e'},
#   {'v'},
#   {'e'},
#   {'v'},
#   {'e'},
#   {'e'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'}],
#  [{'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e'},
#   {'e'},
#   {'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'v'}],
#  [{'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o'},
#   {'o', 'v'},
#   {'o'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'o'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'o'},
#   {'o'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e'},
#   {'e'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e'},
#   {'e'},
#   {'o'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'e'},
#   {'e', 'v'},
#   {'e'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e'},
#   {'e'},
#   {'c'},
#   {'o'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'}],
#  [{'v'},
#   {'o', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'o'},
#   {'o'},
#   {'e'},
#   {'v'},
#   {'e'},
#   {'v'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c'},
#   {'e'},
#   {'o'},
#   {'c', 'e', 'o', 'v'}],
#  [{'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'o', 'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'o'},
#   {'o'},
#   {'o'},
#   {'c'},
#   {'e'},
#   {'e'},
#   {'c'},
#   {'e', 'v'},
#   {'o'},
#   {'v'},
#   {'o'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'o', 'v'},
#   {'v'},
#   {'e'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'}],
#  [{'c', 'e', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'o'},
#   {'o', 'v'},
#   {'e', 'o', 'v'},
#   {'e'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e'},
#   {'v'},
#   {'o'},
#   {'c'},
#   {'e', 'v'},
#   {'o'},
#   {'o'},
#   {'e', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'e', 'o', 'v'}],
#  [{'e', 'v'},
#   {'o', 'v'},
#   {'e', 'v'},
#   {'o', 'v'},
#   {'c'},
#   {'e', 'v'},
#   {'o'},
#   {'e'},
#   {'e'},
#   {'e'},
#   {'c', 'e', 'o', 'v'},
#   {'o'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e'},
#   {'o', 'v'},
#   {'c'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'e'},
#   {'e', 'v'},
#   {'o', 'v'},
#   {'e', 'v'},
#   {'o', 'v'},
#   {'e', 'o'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'e', 'v'}],
#  [{'o', 'v'},
#   {'e', 'v'},
#   {'o'},
#   {'e', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'c', 'o'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'e'},
#   {'o', 'v'},
#   {'c'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'e', 'v'},
#   {'o', 'v'},
#   {'e'},
#   {'o', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'v'},
#   {'c'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'c', 'e'},
#   {'e', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'e', 'v'},
#   {'c'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e'},
#   {'e', 'v'},
#   {'e', 'v'}],
#  [{'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'c', 'o'},
#   {'o'},
#   {'c', 'e', 'o', 'v'},
#   {'c'},
#   {'c', 'e', 'o', 'v'},
#   {'c'},
#   {'c'},
#   {'e'},
#   {'e'},
#   {'o'},
#   {'o'},
#   {'o'},
#   {'c', 'e', 'o', 'v'},
#   {'o'},
#   {'v'},
#   {'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'e', 'v'},
#   {'v'}],
#  [{'e'},
#   {'v'},
#   {'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'e', 'o', 'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'e', 'o'},
#   {'v'},
#   {'e', 'o', 'v'},
#   {'e', 'v'},
#   {'e', 'v'}],
#  [{'v'},
#   {'c', 'o'},
#   {'v'},
#   {'o'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'v'},
#   {'v'}],
#  [{'e', 'v'},
#   {'c'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'o'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c'},
#   {'e', 'v'},
#   {'v'},
#   {'v'},
#   {'e', 'v'}],
#  [{'c', 'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'e', 'v'},
#   {'c', 'o'},
#   {'e'},
#   {'e', 'o', 'v'},
#   {'o'},
#   {'c', 'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'}],
#  [{'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o'},
#   {'e', 'o'},
#   {'v'},
#   {'e'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'c', 'e', 'o'},
#   {'v'},
#   {'v'}],
#  [{'e', 'v'},
#   {'c', 'e'},
#   {'e'},
#   {'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c'},
#   {'o', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'}],
#  [{'e', 'v'},
#   {'v'},
#   {'c', 'e'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e'},
#   {'c', 'e', 'o', 'v'},
#   {'e'},
#   {'o'},
#   {'o'},
#   {'o', 'v'},
#   {'e'},
#   {'c'},
#   {'c'},
#   {'e'},
#   {'e'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o'},
#   {'e', 'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'c', 'e'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e'},
#   {'c', 'e'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e'},
#   {'o', 'v'},
#   {'e'},
#   {'c', 'e'},
#   {'e'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'v'},
#   {'v'},
#   {'e'},
#   {'v'},
#   {'v'},
#   {'e'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'}],
#  [{'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'o'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'o'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'c', 'v'},
#   {'e', 'o'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'o'},
#   {'e', 'v'},
#   {'o'},
#   {'c', 'e', 'o', 'v'},
#   {'c'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'}],
#  [{'e', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e'},
#   {'o'},
#   {'o'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'}],
#  [{'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'o'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'o'},
#   {'e', 'o', 'v'},
#   {'o', 'v'},
#   {'e'},
#   {'e'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e'},
#   {'o', 'v'},
#   {'v'},
#   {'e'},
#   {'c', 'e', 'o', 'v'},
#   {'o'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'c', 'o'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'o'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'}],
#  [{'o', 'v'},
#   {'c', 'e'},
#   {'c', 'o'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c', 'o', 'v'},
#   {'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'c', 'e'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e'},
#   {'o', 'v'},
#   {'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'e', 'v'},
#   {'e'},
#   {'e', 'v'},
#   {'c'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'}],
#  [{'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'e', 'o', 'v'},
#   {'e', 'v'},
#   {'o'},
#   {'e', 'v'},
#   {'e', 'o', 'v'},
#   {'o'},
#   {'e'},
#   {'e'},
#   {'o', 'v'},
#   {'e', 'o', 'v'},
#   {'e'},
#   {'e'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'e', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'o', 'v'},
#   {'e', 'o', 'v'},
#   {'v'},
#   {'o'},
#   {'o', 'v'},
#   {'e'},
#   {'e', 'o', 'v'},
#   {'e'},
#   {'o', 'v'},
#   {'e'},
#   {'o', 'v'}],
#  [{'e', 'o'},
#   {'e', 'o'},
#   {'e'},
#   {'e'},
#   {'v'},
#   {'e'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'}],
#  [{'v'},
#   {'e'},
#   {'e', 'v'},
#   {'v'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'e', 'v'},
#   {'c'},
#   {'c'},
#   {'o', 'v'},
#   {'c', 'e'},
#   {'c'},
#   {'c'},
#   {'v'},
#   {'c', 'e'},
#   {'v'},
#   {'v'},
#   {'c', 'e'},
#   {'v'},
#   {'c', 'e'},
#   {'c', 'e'}],
#  [{'e', 'v'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'o'},
#   {'o'},
#   {'e'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'c', 'o'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o'},
#   {'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c'},
#   {'v'},
#   {'c', 'o'},
#   {'v'},
#   {'c'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'o', 'v'},
#   {'v'},
#   {'v'},
#   {'e', 'v'},
#   {'o'},
#   {'c', 'o', 'v'},
#   {'o'},
#   {'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'v'},
#   {'e', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'e', 'v'},
#   {'v'}],
#  [{'e', 'v'},
#   {'e', 'v'},
#   {'e'},
#   {'c', 'o'},
#   {'c', 'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e'},
#   {'e'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'v'},
#   {'e'},
#   {'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'c'},
#   {'v'},
#   {'v'},
#   {'c'},
#   {'v'},
#   {'c'},
#   {'v'},
#   {'v'},
#   {'e', 'v'},
#   {'v'},
#   {'o'},
#   {'o'},
#   {'v'},
#   {'e'},
#   {'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'}],
#  [{'v'},
#   {'c', 'e', 'o'},
#   {'v'},
#   {'e'},
#   {'v'},
#   {'v'},
#   {'c', 'o'},
#   {'c', 'e', 'o', 'v'},
#   {'e'},
#   {'e'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'v'},
#   {'v'}],
#  [{'e', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'v'},
#   {'c', 'o'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'}],
#  [{'e', 'v'},
#   {'v'},
#   {'c', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'e', 'v'}],
#  [{'e', 'v'},
#   {'o'},
#   {'c', 'e'},
#   {'v'},
#   {'v'},
#   {'e'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'c', 'e', 'v'},
#   {'v'},
#   {'c', 'e'},
#   {'o', 'v'},
#   {'v'},
#   {'v'},
#   {'c'},
#   {'v'},
#   {'v'},
#   {'o', 'v'},
#   {'c', 'v'},
#   {'v'},
#   {'c', 'e', 'v'},
#   {'v'},
#   {'c', 'e'},
#   {'v'},
#   {'c', 'e', 'v'},
#   {'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'v'},
#   {'v'},
#   {'o', 'v'},
#   {'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'o'},
#   {'c', 'o'},
#   {'c'},
#   {'c'},
#   {'o'},
#   {'e', 'o'},
#   {'e'},
#   {'e'},
#   {'e', 'o'}],
#  [{'v'},
#   {'c'},
#   {'v'},
#   {'v'},
#   {'c'},
#   {'o', 'v'},
#   {'c'},
#   {'v'},
#   {'e', 'v'},
#   {'e'},
#   {'v'},
#   {'e'},
#   {'v'},
#   {'e', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'}],
#  [{'v'},
#   {'c', 'v'},
#   {'e', 'v'},
#   {'c', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'v'}],
#  [{'c', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e'},
#   {'e'},
#   {'c', 'o'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'e', 'v'}],
#  [{'e', 'o', 'v'},
#   {'o'},
#   set(),
#   {'o', 'v'},
#   {'o'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'c'},
#   {'c'},
#   {'c'},
#   {'o', 'v'},
#   {'c', 'o'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'v'}],
#  [{'c'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'o'},
#   {'c', 'v'},
#   {'v'},
#   {'o', 'v'},
#   {'e'},
#   {'c', 'e'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'c', 'e', 'v'},
#   {'v'},
#   {'o'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'c'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'}],
#  [{'e', 'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o'},
#   {'o'},
#   {'o'},
#   {'e'},
#   {'c'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'}],
#  [{'c'},
#   {'e', 'v'},
#   {'c', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'v'},
#   {'v'},
#   {'c', 'v'},
#   {'e', 'v'},
#   {'c', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o'},
#   {'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'v'},
#   {'v'},
#   {'v'},
#   {'e'},
#   {'c', 'e', 'o', 'v'},
#   {'e'},
#   {'c'},
#   {'v'},
#   {'v'},
#   {'e', 'v'}],
#  [{'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e'},
#   {'e'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'o'},
#   {'e', 'o'},
#   {'v'},
#   {'o'},
#   {'e', 'v'},
#   {'v'},
#   {'c', 'v'},
#   {'c'},
#   {'v'},
#   {'e'},
#   {'v'},
#   {'c', 'v'},
#   {'c'},
#   {'o'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'e', 'v'},
#   {'e', 'v'},
#   {'c', 'o'},
#   {'e', 'v'},
#   {'c', 'o'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c', 'o'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'e', 'v'}],
#  [{'c'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'}],
#  [{'v'},
#   {'e', 'v'},
#   {'c', 'v'},
#   {'v'},
#   {'c', 'v'},
#   {'c', 'v'},
#   {'c', 'v'},
#   {'c', 'e', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'}],
#  [{'e', 'o', 'v'},
#   {'c', 'o', 'v'},
#   {'c', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'c'},
#   {'c', 'e', 'o', 'v'},
#   {'e'},
#   {'c', 'e', 'o', 'v'},
#   {'c'},
#   {'c', 'e', 'o', 'v'},
#   {'e'},
#   {'c', 'e', 'o', 'v'},
#   {'e'},
#   {'c'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'c', 'o', 'v'},
#   {'c'},
#   {'c', 'v'},
#   {'c'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'o'},
#   {'c'},
#   {'o'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'}],
#  [{'e', 'v'},
#   {'e', 'v'},
#   {'e'},
#   {'e', 'v'},
#   {'e'},
#   {'v'},
#   {'o'},
#   {'c'},
#   {'c', 'e', 'o', 'v'},
#   {'e'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'o'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'o', 'v'},
#   {'e', 'v'},
#   {'e', 'v'}],
#  [{'e', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'}],
#  [{'c'},
#   {'v'},
#   {'o', 'v'},
#   {'v'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e'},
#   {'e'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'}],
#  [{'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'o', 'v'},
#   {'v'},
#   {'c'},
#   {'e', 'v'},
#   {'e'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'}],
#  [{'e', 'o', 'v'},
#   {'c', 'e'},
#   {'v'},
#   {'e', 'o', 'v'},
#   {'c', 'e'},
#   {'o', 'v'},
#   {'v'},
#   {'c'},
#   {'c', 'e', 'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'e', 'v'},
#   {'o', 'v'},
#   {'v'},
#   {'o'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'c', 'o'},
#   {'e', 'o', 'v'},
#   {'v'},
#   {'o'},
#   {'e', 'o', 'v'},
#   {'e'},
#   {'c', 'v'},
#   {'e'},
#   {'e'},
#   {'e'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o'},
#   {'o'},
#   {'v'},
#   {'e', 'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'c', 'o'},
#   {'e', 'v'},
#   {'v'},
#   {'v'},
#   {'e', 'v'},
#   {'e'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'}],
#  [{'v'},
#   {'c', 'v'},
#   {'e', 'v'},
#   {'o', 'v'},
#   {'e', 'v'},
#   {'o', 'v'},
#   {'e', 'v'},
#   {'c', 'v'},
#   {'c'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'o'},
#   {'e'},
#   {'e', 'o', 'v'},
#   {'o', 'v'},
#   {'o'},
#   {'e', 'v'},
#   {'o', 'v'},
#   {'v'},
#   {'e'},
#   {'e'},
#   {'o', 'v'}],
#  [{'e', 'v'},
#   {'e', 'v'},
#   {'c'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'c', 'o'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'v'}],
#  [{'e', 'v'},
#   {'o', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'o', 'v'},
#   {'e', 'o', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'o', 'v'},
#   {'o'},
#   {'o'},
#   {'c'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'c'},
#   {'e', 'v'},
#   {'v'},
#   {'v'},
#   {'e', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e'},
#   {'e'},
#   {'e', 'v'},
#   {'e'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'v'},
#   {'v'}],
#  [{'e'},
#   {'o', 'v'},
#   {'v'},
#   {'o', 'v'},
#   {'v'},
#   {'o'},
#   {'o'},
#   {'o'},
#   {'c', 'e', 'o', 'v'},
#   {'e'},
#   {'c'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'c', 'e', 'o', 'v'},
#   {'e'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c'},
#   {'c'},
#   {'c', 'e', 'o', 'v'}],
#  [{'e', 'v'},
#   {'c', 'e', 'o'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'e'},
#   {'e'},
#   {'v'},
#   {'e'},
#   {'c'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'}],
#  [{'o', 'v'},
#   {'e', 'v'},
#   {'c'},
#   {'e', 'v'},
#   {'c', 'e'},
#   {'e'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e'},
#   {'v'},
#   {'o', 'v'},
#   {'v'},
#   {'o'},
#   {'o', 'v'}],
#  [{'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c'},
#   {'e', 'v'},
#   {'o', 'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c'},
#   {'e'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'c', 'o'},
#   {'o', 'v'},
#   {'c', 'o'}],
#  [{'v'},
#   {'v'},
#   {'e', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'c', 'o'},
#   {'v'},
#   {'v'},
#   {'o'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'e', 'v'},
#   {'v'},
#   {'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'v'}],
#  [{'e'},
#   {'v'},
#   {'v'},
#   {'e'},
#   {'e'},
#   {'e'},
#   {'e'},
#   {'e'},
#   {'v'},
#   {'e'},
#   {'e'},
#   {'e'}],
#  [{'e', 'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'c', 'e', 'o'},
#   {'e', 'o', 'v'},
#   {'v'},
#   {'e'},
#   {'c', 'o'},
#   {'c'},
#   {'c', 'e', 'o', 'v'},
#   {'o'},
#   {'c', 'o', 'v'},
#   {'c'},
#   {'o'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'e', 'o'},
#   {'o', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'e', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'e'},
#   {'e'},
#   {'e'},
#   {'c', 'o'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'o', 'v'}],
#  [{'e', 'o', 'v'},
#   {'c', 'v'},
#   {'v'},
#   {'c', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'}],
#  [{'e', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e'},
#   {'c', 'e', 'o'},
#   {'c', 'o'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'c', 'o'},
#   {'c'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'e', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'c', 'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'}],
#  [{'e', 'v'}, {'e', 'v'}, {'c', 'e', 'o', 'v'}, {'e', 'v'}],
#  [{'c', 'o'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'c'},
#   {'c'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'}],
#  [{'o', 'v'},
#   {'e', 'v'},
#   {'e', 'o', 'v'},
#   {'o', 'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'v'},
#   {'v'},
#   {'e', 'o', 'v'},
#   {'o'},
#   {'e'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'e', 'o'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'e', 'o'},
#   {'e', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c'},
#   {'o'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'}],
#  [{'o', 'v'},
#   {'c'},
#   {'v'},
#   {'c', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'o', 'v'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'o', 'v'}],
#  [{'o'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o'},
#   {'c', 'e', 'v'}],
#  [{'o', 'v'},
#   {'o', 'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'o'},
#   {'o'},
#   {'o'},
#   {'o', 'v'},
#   {'o'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'o'},
#   {'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'o'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'c', 'e', 'o', 'v'},
#   {'c', 'e', 'v'},
#   {'e', 'o', 'v'},
#   {'v'},
#   {'v'},
#   {'o'},
#   {'o'},
#   {'o'},
#   {'c', 'e', 'o', 'v'},
#   {'e'},
#   {'c'},
#   {'c', 'e', 'o', 'v'},
#   {'o'},
#   {'e'},
#   {'c'},
#   {'c', 'v'},
#   {'e', 'o', 'v'},
#   {'o'},
#   {'e'},
#   {'o', 'v'},
#   {'e'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'c', 'o'},
#   {'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'v'},
#   {'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'o', 'v'}],
#  [{'e'},
#   {'e', 'v'},
#   {'e'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e'},
#   {'v'},
#   {'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'e'},
#   {'e'},
#   {'v'},
#   {'e'}],
#  [{'e', 'v'},
#   {'c'},
#   {'c', 'v'},
#   {'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'v'},
#   {'c'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'v'}],
#  [{'e', 'o', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o'},
#   {'e'},
#   {'e'},
#   {'v'},
#   {'e'},
#   {'v'},
#   {'c', 'o'},
#   {'o'},
#   {'e', 'v'},
#   {'c'},
#   {'c', 'e', 'o', 'v'},
#   {'c'},
#   {'c'},
#   {'c'},
#   {'c'},
#   {'c'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'c'},
#   {'c'},
#   {'c'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'o'},
#   {'e', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'o', 'v'}],
#  [{'c', 'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'o'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'v'},
#   {'o'},
#   {'c', 'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'o', 'v'},
#   {'o'},
#   {'v'},
#   {'o'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'o'},
#   {'e', 'v'},
#   {'e', 'o', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'c'},
#   {'e', 'o', 'v'},
#   {'e', 'o', 'v'}],
#  [{'e', 'v'},
#   {'e', 'v'},
#   {'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'e', 'v'}],
#  [{'v'},
#   {'e', 'v'},
#   {'o', 'v'},
#   {'o', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c', 'e', 'o', 'v'},
#   {'o', 'v'},
#   {'e', 'v'},
#   {'e', 'v'},
#   {'c', 'o'},
#   {'o', 'v'},
#   {'v'},
#   {'o', 'v'},
#   {'e', 'v'}]]

# %%
solution_tracker_bigrams = Counter()
total_pairs = 0
for conv in solutions_per_dialogue:
    elements = list(conv)
    els = ["".join(e) for e in elements]
    processed = ['BEGIN', *els, "END"]
    for pr, current in zip(processed[:-1], processed[1:]):
        total_pairs += 1
        solution_tracker_bigrams.update(["{}->{}".format(pr, current)])

# %%
solution_tracker_bigrams.most_common(1000)
# Out:
# [('v->v', 168),
#  ('ev->ev', 157),
#  ('ov->ov', 116),
#  ('v->ev', 80),
#  ('ev->v', 64),
#  ('e->v', 40),
#  ('e->e', 40),
#  ('BEGIN->ev', 39),
#  ('ov->END', 38),
#  ('ev->END', 33),
#  ('oecv->oecv', 33),
#  ('ov->v', 32),
#  ('v->e', 32),
#  ('ocev->ocev', 31),
#  ('ev->ov', 29),
#  ('ev->oecv', 29),
#  ('v->ov', 28),
#  ('o->o', 28),
#  ('ev->e', 27),
#  ('ov->ev', 26),
#  ('v->o', 26),
#  ('oecv->ev', 25),
#  ('e->ov', 24),
#  ('c->ev', 23),
#  ('ev->o', 22),
#  ('BEGIN->v', 20),
#  ('c->v', 20),
#  ('v->oecv', 19),
#  ('o->ov', 19),
#  ('oecv->v', 17),
#  ('v->END', 17),
#  ('c->c', 17),
#  ('eov->eov', 17),
#  ('o->v', 16),
#  ('c->ov', 15),
#  ('ev->c', 15),
#  ('e->ev', 15),
#  ('e->c', 14),
#  ('o->ev', 14),
#  ('oecv->ov', 14),
#  ('oecv->e', 14),
#  ('o->e', 13),
#  ('v->c', 13),
#  ('ov->o', 13),
#  ('ov->oecv', 12),
#  ('ov->e', 12),
#  ('v->ocev', 12),
#  ('ocev->v', 12),
#  ('ev->ocev', 12),
#  ('BEGIN->ov', 11),
#  ('ec->v', 11),
#  ('v->eov', 11),
#  ('o->oecv', 11),
#  ('ov->c', 10),
#  ('eocv->ev', 10),
#  ('e->oecv', 9),
#  ('ocev->ov', 9),
#  ('oecv->END', 9),
#  ('oecv->c', 9),
#  ('ov->ocev', 9),
#  ('ocev->ev', 9),
#  ('cv->v', 9),
#  ('v->cv', 9),
#  ('e->o', 8),
#  ('eov->o', 8),
#  ('oc->ev', 8),
#  ('o->c', 7),
#  ('v->ec', 7),
#  ('BEGIN->eov', 7),
#  ('eov->ev', 7),
#  ('c->o', 7),
#  ('eov->v', 7),
#  ('eov->ov', 7),
#  ('ev->oc', 7),
#  ('v->oc', 7),
#  ('ec->ov', 6),
#  ('BEGIN->oecv', 6),
#  ('c->eocv', 6),
#  ('eocv->v', 6),
#  ('c->e', 6),
#  ('eov->END', 6),
#  ('BEGIN->e', 6),
#  ('oc->oecv', 6),
#  ('v->coev', 6),
#  ('oc->v', 6),
#  ('v->eocv', 6),
#  ('ev->cv', 6),
#  ('c->oecv', 6),
#  ('ecv->v', 6),
#  ('ov->ec', 5),
#  ('ov->eocv', 5),
#  ('eov->e', 5),
#  ('ev->eocv', 5),
#  ('eo->v', 5),
#  ('ev->eov', 5),
#  ('o->eov', 5),
#  ('ocev->c', 5),
#  ('oc->ov', 5),
#  ('eocv->o', 5),
#  ('o->eocv', 5),
#  ('ov->eov', 5),
#  ('cv->ev', 5),
#  ('BEGIN->c', 5),
#  ('ev->ec', 4),
#  ('c->cv', 4),
#  ('e->ec', 4),
#  ('eocv->c', 4),
#  ('ev->co', 4),
#  ('o->ocev', 4),
#  ('ocev->o', 4),
#  ('eo->ev', 4),
#  ('eov->c', 4),
#  ('coev->eov', 4),
#  ('e->eov', 4),
#  ('ec->e', 4),
#  ('eov->ocev', 4),
#  ('ocev->eov', 4),
#  ('ocev->END', 4),
#  ('oecv->o', 4),
#  ('ocev->ec', 4),
#  ('e->ocev', 4),
#  ('oecv->oc', 4),
#  ('ov->oc', 4),
#  ('e->eocv', 4),
#  ('eocv->ov', 4),
#  ('cv->c', 4),
#  ('eocv->e', 4),
#  ('ec->ev', 3),
#  ('c->ecv', 3),
#  ('coev->eo', 3),
#  ('ev->coev', 3),
#  ('c->eov', 3),
#  ('coev->v', 3),
#  ('ecv->ocev', 3),
#  ('oecv->cv', 3),
#  ('cv->oecv', 3),
#  ('BEGIN->eocv', 3),
#  ('oecv->eov', 3),
#  ('eov->ec', 3),
#  ('ev->eo', 3),
#  ('ev->oec', 3),
#  ('ocev->e', 3),
#  ('BEGIN->eo', 3),
#  ('v->ecv', 3),
#  ('BEGIN->oc', 3),
#  ('c->coev', 3),
#  ('coev->coev', 3),
#  ('o->eo', 2),
#  ('cv->e', 2),
#  ('ev->ecv', 2),
#  ('ecv->ev', 2),
#  ('co->ev', 2),
#  ('ev->ocv', 2),
#  ('ocv->ov', 2),
#  ('ov->ocv', 2),
#  ('eo->eo', 2),
#  ('eo->eov', 2),
#  ('eov->coev', 2),
#  ('oc->eov', 2),
#  ('eov->oecv', 2),
#  ('BEGIN->ocev', 2),
#  ('ov->cv', 2),
#  ('coev->END', 2),
#  ('eo->oecv', 2),
#  ('coev->ev', 2),
#  ('BEGIN->ecv', 2),
#  ('o->ecv', 2),
#  ('ec->ocev', 2),
#  ('ec->ec', 2),
#  ('ocev->eocv', 2),
#  ('oc->ocev', 2),
#  ('ocv->v', 2),
#  ('eo->e', 2),
#  ('e->co', 2),
#  ('BEGIN->o', 2),
#  ('oc->c', 2),
#  ('e->oc', 2),
#  ('cv->cv', 2),
#  ('cov->c', 2),
#  ('oecv->ocv', 2),
#  ('e->END', 2),
#  ('eocv->eov', 1),
#  ('eo->c', 1),
#  ('oecv->ec', 1),
#  ('ecv->e', 1),
#  ('BEGIN->coev', 1),
#  ('eov->eo', 1),
#  ('c->eo', 1),
#  ('eov->oc', 1),
#  ('eocv->oc', 1),
#  ('ec->o', 1),
#  ('BEGIN->', 1),
#  ('->oecv', 1),
#  ('co->e', 1),
#  ('c->oc', 1),
#  ('eocv->cv', 1),
#  ('ocv->oc', 1),
#  ('o->coev', 1),
#  ('oecv->ocev', 1),
#  ('ov->eo', 1),
#  ('co->o', 1),
#  ('v->co', 1),
#  ('co->v', 1),
#  ('oc->e', 1),
#  ('oec->eo', 1),
#  ('v->oec', 1),
#  ('oec->v', 1),
#  ('BEGIN->ec', 1),
#  ('eocv->eocv', 1),
#  ('eocv->ocev', 1),
#  ('cv->eo', 1),
#  ('ocev->oc', 1),
#  ('ec->oc', 1),
#  ('ec->c', 1),
#  ('ec->END', 1),
#  ('o->ocv', 1),
#  ('ocv->o', 1),
#  ('co->cov', 1),
#  ('cov->ov', 1),
#  ('v->oce', 1),
#  ('oce->v', 1),
#  ('o->ec', 1),
#  ('o->oc', 1),
#  ('e->eo', 1),
#  ('eo->END', 1),
#  ('BEGIN->cv', 1),
#  ('oecv->eocv', 1),
#  ('o->', 1),
#  ('->ov', 1),
#  ('o->cv', 1),
#  ('cv->ocev', 1),
#  ('cv->eocv', 1),
#  ('oc->eo', 1),
#  ('cv->ecv', 1),
#  ('eov->cov', 1),
#  ('cov->cov', 1),
#  ('cov->eov', 1),
#  ('ov->cov', 1),
#  ('e->cv', 1),
#  ('coev->e', 1),
#  ('oec->ev', 1),
#  ('oc->END', 1),
#  ('BEGIN->eoc', 1),
#  ('eoc->eov', 1),
#  ('co->c', 1),
#  ('o->cov', 1),
#  ('eo->ov', 1),
#  ('eov->cv', 1),
#  ('e->oec', 1),
#  ('oec->oc', 1),
#  ('eov->ecv', 1),
#  ('ecv->oecv', 1),
#  ('BEGIN->co', 1),
#  ('co->ov', 1),
#  ('ocv->oecv', 1),
#  ('oecv->coev', 1),
#  ('coev->o', 1),
#  ('ecv->END', 1),
#  ('eocv->ecv', 1),
#  ('ecv->eov', 1),
#  ('cv->eov', 1),
#  ('oec->e', 1),
#  ('oc->o', 1),
#  ('coev->c', 1),
#  ('cv->o', 1)]

# %%
solution_tracker_trigrams = Counter()
total_pairs = 0
for conv in solutions_per_dialogue:
    elements = list(conv)
    els = ["".join(e) for e in elements]
    processed = ['BEGIN', *els, "END"]
    for pr, current, next_ in zip(processed[:-2], processed[1:-1], processed[2:]):
        total_pairs += 1
        solution_tracker_trigrams.update(["{}->{}->{}".format(pr, current, next_)])

# %%
solution_tracker_trigrams.most_common(50)
# Out:
# [('v->v->v', 74),
#  ('ev->ev->ev', 65),
#  ('ov->ov->ov', 49),
#  ('v->ev->ev', 31),
#  ('ov->ov->END', 29),
#  ('ev->v->ev', 25),
#  ('v->v->ev', 22),
#  ('v->ev->v', 21),
#  ('ev->v->v', 21),
#  ('ev->ev->END', 20),
#  ('ocev->ocev->ocev', 17),
#  ('ev->ev->e', 15),
#  ('ev->ev->v', 15),
#  ('v->ov->ov', 14),
#  ('v->v->END', 14),
#  ('e->v->v', 14),
#  ('BEGIN->ev->ev', 13),
#  ('ev->oecv->ev', 11),
#  ('v->v->oecv', 11),
#  ('e->ov->ov', 11),
#  ('e->e->v', 11),
#  ('v->e->v', 11),
#  ('ov->ev->ev', 10),
#  ('ov->v->v', 10),
#  ('o->ov->ov', 10),
#  ('oecv->oecv->oecv', 10),
#  ('c->v->v', 10),
#  ('ev->ev->oecv', 10),
#  ('v->e->e', 9),
#  ('c->ev->ev', 9),
#  ('e->v->ev', 9),
#  ('ov->ov->oecv', 9),
#  ('e->v->e', 9),
#  ('ev->e->e', 8),
#  ('o->o->o', 8),
#  ('v->o->o', 8),
#  ('ov->ov->v', 8),
#  ('eov->eov->eov', 8),
#  ('ev->ov->ov', 8),
#  ('oecv->v->v', 7),
#  ('ev->o->ev', 7),
#  ('v->v->e', 7),
#  ('v->v->ov', 7),
#  ('ov->e->ov', 7),
#  ('ocev->v->v', 7),
#  ('BEGIN->v->ev', 7),
#  ('ev->ov->ev', 7),
#  ('c->ov->ov', 7),
#  ('ev->ev->ocev', 7),
#  ('ev->e->v', 7)]
